# %%
import yfinance as yf
import pandas as pd

# %%
nvda = yf.Ticker("NVDA")

# %%
nvda = nvda.history(period="max", interval="1wk")

# %%
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1999-01-18 00:00:00-05:00    0.401407    0.447999    0.356010    0.376319
# 1999-01-25 00:00:00-05:00    0.406185    0.428884    0.363177    0.363177
# 1999-02-01 00:00:00-05:00    0.363177    0.382293    0.330922    0.378708
# 1999-02-08 00:00:00-05:00    0.381098    0.401407    0.341674    0.399018
# 1999-02-15 00:00:00-05:00    0.406185    0.422911    0.360788    0.399018
# ...                               ...         ...         ...         ...
# 2023-05-08 00:00:00-04:00  285.190485  292.169774  280.430968  283.370667
# 2023-05-15 00:00:00-04:00  285.050490  318.247067  281.490860  312.607666
# 2023-05-22 00:00:00-04:00  308.978024  394.759121  298.029145  389.419678
# 2023-05-29 00:00:00-04:00  405.908021  419.336624  378.180878  393.229309
# 2023-06-05 00:00:00-04:00  389.049722  397.068881  373.521331  387.659882
#
#                               Volume  Dividends  Stock Splits
# Date
# 1999-01-18 00:00:00-05:00  271468800       0.00           0.0
# 1999-01-25 00:00:00-05:00  156960000       0.00           0.0
# 1999-02-01 00:00:00-05:00   81268800       0.00           0.0
# 1999-02-08 00:00:00-05:00   63124800       0.00           0.0
# 1999-02-15 00:00:00-05:00   42480000       0.00           0.0
# ...                              ...        ...           ...
# 2023-05-08 00:00:00-04:00  162537400       0.00           0.0
# 2023-05-15 00:00:00-04:00  239771500       0.00           0.0
# 2023-05-22 00:00:00-04:00  370798000       0.00           0.0
# 2023-05-29 00:00:00-04:00  304350900       0.00           0.0
# 2023-06-05 00:00:00-04:00  214181300       0.04           0.0
#
# [1273 rows x 7 columns]

# %%
nvda['Open %change'] = nvda['Open'] / nvda['Open'].shift(1)
nvda['Close %change'] = nvda['Close'] / nvda['Close'].shift(1)
nvda['Low %change'] = nvda['Low'] / nvda['Low'].shift(1)
nvda['High %change'] = nvda['High'] / nvda['High'].shift(1)
nvda['Volume %change'] = nvda['Volume'] / nvda['Volume'].shift(1)
nvda = nvda.drop(nvda.index[0])
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1999-01-25 00:00:00-05:00    0.406185    0.428884    0.363177    0.363177
# 1999-02-01 00:00:00-05:00    0.363177    0.382293    0.330922    0.378708
# 1999-02-08 00:00:00-05:00    0.381098    0.401407    0.341674    0.399018
# 1999-02-15 00:00:00-05:00    0.406185    0.422911    0.360788    0.399018
# 1999-02-22 00:00:00-05:00    0.406185    0.501759    0.379903    0.419327
# ...                               ...         ...         ...         ...
# 2023-05-08 00:00:00-04:00  285.190485  292.169774  280.430968  283.370667
# 2023-05-15 00:00:00-04:00  285.050490  318.247067  281.490860  312.607666
# 2023-05-22 00:00:00-04:00  308.978024  394.759121  298.029145  389.419678
# 2023-05-29 00:00:00-04:00  405.908021  419.336624  378.180878  393.229309
# 2023-06-05 00:00:00-04:00  389.049722  397.068881  373.521331  387.659882
#
#                               Volume  Dividends  Stock Splits  Open %change  \
# Date
# 1999-01-25 00:00:00-05:00  156960000       0.00           0.0      1.011904
# 1999-02-01 00:00:00-05:00   81268800       0.00           0.0      0.894118
# 1999-02-08 00:00:00-05:00   63124800       0.00           0.0      1.049344
# 1999-02-15 00:00:00-05:00   42480000       0.00           0.0      1.065829
# 1999-02-22 00:00:00-05:00  127785600       0.00           0.0      1.000000
# ...                              ...        ...           ...           ...
# 2023-05-08 00:00:00-04:00  162537400       0.00           0.0      1.024497
# 2023-05-15 00:00:00-04:00  239771500       0.00           0.0      0.999509
# 2023-05-22 00:00:00-04:00  370798000       0.00           0.0      1.083941
# 2023-05-29 00:00:00-04:00  304350900       0.00           0.0      1.313712
# 2023-06-05 00:00:00-04:00  214181300       0.04           0.0      0.958468
#
#                            Close %change  Low %change  High %change  \
# Date
# 1999-01-25 00:00:00-05:00       0.965079     1.020133      0.957334
# 1999-02-01 00:00:00-05:00       1.042763     0.911185      0.891365
# 1999-02-08 00:00:00-05:00       1.053630     1.032492      1.049999
# 1999-02-15 00:00:00-05:00       1.000000     1.055943      1.053573
# 1999-02-22 00:00:00-05:00       1.050897     1.052982      1.186439
# ...                                  ...          ...           ...
# 2023-05-08 00:00:00-04:00       0.988145     1.029589      1.005575
# 2023-05-15 00:00:00-04:00       1.103176     1.003780      1.089254
# 2023-05-22 00:00:00-04:00       1.245714     1.058752      1.240417
# 2023-05-29 00:00:00-04:00       1.009783     1.268939      1.062259
# 2023-06-05 00:00:00-04:00       0.985837     0.987679      0.946898
#
#                            Volume %change
# Date
# 1999-01-25 00:00:00-05:00        0.578188
# 1999-02-01 00:00:00-05:00        0.517768
# 1999-02-08 00:00:00-05:00        0.776741
# 1999-02-15 00:00:00-05:00        0.672953
# 1999-02-22 00:00:00-05:00        3.008136
# ...                                   ...
# 2023-05-08 00:00:00-04:00        0.797022
# 2023-05-15 00:00:00-04:00        1.475177
# 2023-05-22 00:00:00-04:00        1.546464
# 2023-05-29 00:00:00-04:00        0.820800
# 2023-06-05 00:00:00-04:00        0.703731
#
# [1272 rows x 12 columns]

# %%
nvda.index
# Out:
# DatetimeIndex(['1999-01-25 00:00:00-05:00', '1999-02-01 00:00:00-05:00',
#                '1999-02-08 00:00:00-05:00', '1999-02-15 00:00:00-05:00',
#                '1999-02-22 00:00:00-05:00', '1999-03-01 00:00:00-05:00',
#                '1999-03-08 00:00:00-05:00', '1999-03-15 00:00:00-05:00',
#                '1999-03-22 00:00:00-05:00', '1999-03-29 00:00:00-05:00',
#                ...
#                '2023-04-03 00:00:00-04:00', '2023-04-10 00:00:00-04:00',
#                '2023-04-17 00:00:00-04:00', '2023-04-24 00:00:00-04:00',
#                '2023-05-01 00:00:00-04:00', '2023-05-08 00:00:00-04:00',
#                '2023-05-15 00:00:00-04:00', '2023-05-22 00:00:00-04:00',
#                '2023-05-29 00:00:00-04:00', '2023-06-05 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=1272, freq=None)

# %%
nvda.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del nvda["Dividends"]
del nvda["Stock Splits"]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
nvda["NextYear"] = nvda["Close"].shift(-50)

# %%
nvda["Target"] = nvda["NextYear"]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["Close", "Volume", "Open", "High", "Low", "Open %change", "Close %change", "Low %change", "High %change", "Volume %change"]

# %%
train = nvda.iloc[:-50]
test = nvda

# %%
reg.fit(train[predictors],train["Target"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.15146e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
combined = pd.concat([test["Target"], pd.Series(predictions, index=test.index)], axis=1)

# %%
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#                              actual  predictions
# Date
# 1999-01-25 00:00:00-05:00  0.839849     8.011807
# 1999-02-01 00:00:00-05:00  0.855379    10.246927
# 1999-02-08 00:00:00-05:00  0.714409    10.719660
# 1999-02-15 00:00:00-05:00  0.775337    10.493197
# 1999-02-22 00:00:00-05:00  0.955731    16.336485
# ...                             ...          ...
# 2023-05-08 00:00:00-04:00       NaN   338.872151
# 2023-05-15 00:00:00-04:00       NaN   298.949147
# 2023-05-22 00:00:00-04:00       NaN   223.355368
# 2023-05-29 00:00:00-04:00       NaN   420.107445
# 2023-06-05 00:00:00-04:00       NaN   453.350669
#
# [1272 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
myResults = combined.iloc[-60:]

# %%
myResults.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
myResults
# Out:
#                                actual  predictions
# Date
# 2022-04-18 00:00:00-04:00  270.342010   181.209303
# 2022-04-25 00:00:00-04:00  267.552307   198.714532
# 2022-05-02 00:00:00-04:00  271.161926   176.098819
# 2022-05-09 00:00:00-04:00  277.461273   191.146071
# 2022-05-16 00:00:00-04:00  286.770325   165.479144
# 2022-05-23 00:00:00-04:00  283.370667   159.250098
# 2022-05-30 00:00:00-04:00  312.607666   210.269879
# 2022-06-06 00:00:00-04:00  389.419678   182.461357
# 2022-06-13 00:00:00-04:00  393.229309   172.648905
# 2022-06-20 00:00:00-04:00  387.659882   196.896097
# 2022-06-27 00:00:00-04:00         NaN   147.677368
# 2022-07-04 00:00:00-04:00         NaN   150.909419
# 2022-07-11 00:00:00-04:00         NaN   185.854747
# 2022-07-18 00:00:00-04:00         NaN   165.479768
# 2022-07-25 00:00:00-04:00         NaN   192.735626
# 2022-08-01 00:00:00-04:00         NaN   212.124504
# 2022-08-08 00:00:00-04:00         NaN   197.966410
# 2022-08-15 00:00:00-04:00         NaN   204.039434
# 2022-08-22 00:00:00-04:00         NaN   180.226566
# 2022-08-29 00:00:00-04:00         NaN   128.415349
# 2022-09-05 00:00:00-04:00         NaN   162.554242
# 2022-09-12 00:00:00-04:00         NaN   143.807814
# 2022-09-19 00:00:00-04:00         NaN   121.335291
# 2022-09-26 00:00:00-04:00         NaN   141.924212
# 2022-10-03 00:00:00-04:00         NaN   112.725811
# 2022-10-10 00:00:00-04:00         NaN   128.080745
# 2022-10-17 00:00:00-04:00         NaN   126.411666
# 2022-10-24 00:00:00-04:00         NaN   135.727745
# 2022-10-31 00:00:00-04:00         NaN   161.781005
# 2022-11-07 00:00:00-05:00         NaN   142.825582
# 2022-11-14 00:00:00-05:00         NaN   159.589057
# 2022-11-21 00:00:00-05:00         NaN   171.402299
# 2022-11-28 00:00:00-05:00         NaN   178.065639
# 2022-12-05 00:00:00-05:00         NaN   182.044031
# 2022-12-12 00:00:00-05:00         NaN   151.510537
# 2022-12-19 00:00:00-05:00         NaN   173.889043
# 2022-12-26 00:00:00-05:00         NaN   177.434615
# 2023-01-02 00:00:00-05:00         NaN   182.598327
# 2023-01-09 00:00:00-05:00         NaN   172.202878
# 2023-01-16 00:00:00-05:00         NaN   202.097169
# 2023-01-23 00:00:00-05:00         NaN   184.889415
# 2023-01-30 00:00:00-05:00         NaN   198.547442
# 2023-02-06 00:00:00-05:00         NaN   204.680989
# 2023-02-13 00:00:00-05:00         NaN   221.067831
# 2023-02-20 00:00:00-05:00         NaN   206.344622
# 2023-02-27 00:00:00-05:00         NaN   287.136103
# 2023-03-06 00:00:00-05:00         NaN   264.003837
# 2023-03-13 00:00:00-04:00         NaN   215.782684
# 2023-03-20 00:00:00-04:00         NaN   277.504834
# 2023-03-27 00:00:00-04:00         NaN   317.026149
# 2023-04-03 00:00:00-04:00         NaN   320.383203
# 2023-04-10 00:00:00-04:00         NaN   309.266097
# 2023-04-17 00:00:00-04:00         NaN   301.806485
# 2023-04-24 00:00:00-04:00         NaN   327.961717
# 2023-05-01 00:00:00-04:00         NaN   327.206069
# 2023-05-08 00:00:00-04:00         NaN   338.872151
# 2023-05-15 00:00:00-04:00         NaN   298.949147
# 2023-05-22 00:00:00-04:00         NaN   223.355368
# 2023-05-29 00:00:00-04:00         NaN   420.107445
# 2023-06-05 00:00:00-04:00         NaN   453.350669

# %%
ourLow = myResults["predictions"].min()
ourLow
# Out:
# 112.72581111730791

# %%
myResults.loc[myResults["predictions"]==ourLow]
# Out:
#                            actual  predictions
# Date
# 2022-10-03 00:00:00-04:00     NaN   112.725811

# %%
ourHigh = myResults["predictions"].max()
ourHigh
# Out:
# 453.3506686809594

# %%
myResults.loc[myResults["predictions"]==ourHigh]
# Out:
#                            actual  predictions
# Date
# 2023-06-05 00:00:00-04:00     NaN   453.350669

# %%
lastMonth = myResults.iloc[-20:]

# %%
lastMonth
# Out:
#                            actual  predictions
# Date
# 2023-01-23 00:00:00-05:00     NaN   184.889415
# 2023-01-30 00:00:00-05:00     NaN   198.547442
# 2023-02-06 00:00:00-05:00     NaN   204.680989
# 2023-02-13 00:00:00-05:00     NaN   221.067831
# 2023-02-20 00:00:00-05:00     NaN   206.344622
# 2023-02-27 00:00:00-05:00     NaN   287.136103
# 2023-03-06 00:00:00-05:00     NaN   264.003837
# 2023-03-13 00:00:00-04:00     NaN   215.782684
# 2023-03-20 00:00:00-04:00     NaN   277.504834
# 2023-03-27 00:00:00-04:00     NaN   317.026149
# 2023-04-03 00:00:00-04:00     NaN   320.383203
# 2023-04-10 00:00:00-04:00     NaN   309.266097
# 2023-04-17 00:00:00-04:00     NaN   301.806485
# 2023-04-24 00:00:00-04:00     NaN   327.961717
# 2023-05-01 00:00:00-04:00     NaN   327.206069
# 2023-05-08 00:00:00-04:00     NaN   338.872151
# 2023-05-15 00:00:00-04:00     NaN   298.949147
# 2023-05-22 00:00:00-04:00     NaN   223.355368
# 2023-05-29 00:00:00-04:00     NaN   420.107445
# 2023-06-05 00:00:00-04:00     NaN   453.350669

# %%
lastMonth["predictions"]
# Out:
# Date
# 2023-01-23 00:00:00-05:00    184.889415
# 2023-01-30 00:00:00-05:00    198.547442
# 2023-02-06 00:00:00-05:00    204.680989
# 2023-02-13 00:00:00-05:00    221.067831
# 2023-02-20 00:00:00-05:00    206.344622
# 2023-02-27 00:00:00-05:00    287.136103
# 2023-03-06 00:00:00-05:00    264.003837
# 2023-03-13 00:00:00-04:00    215.782684
# 2023-03-20 00:00:00-04:00    277.504834
# 2023-03-27 00:00:00-04:00    317.026149
# 2023-04-03 00:00:00-04:00    320.383203
# 2023-04-10 00:00:00-04:00    309.266097
# 2023-04-17 00:00:00-04:00    301.806485
# 2023-04-24 00:00:00-04:00    327.961717
# 2023-05-01 00:00:00-04:00    327.206069
# 2023-05-08 00:00:00-04:00    338.872151
# 2023-05-15 00:00:00-04:00    298.949147
# 2023-05-22 00:00:00-04:00    223.355368
# 2023-05-29 00:00:00-04:00    420.107445
# 2023-06-05 00:00:00-04:00    453.350669
# Name: predictions, dtype: float64

# %%
priceTarget = lastMonth["predictions"].mean()
priceTarget
# Out:
# 284.9121128398018
